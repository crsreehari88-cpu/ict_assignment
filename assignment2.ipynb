# %% [markdown]
# <a href="https://colab.research.google.com/github/crsreehari88-cpu/ict_assignment/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. FizzBuzz
# FizzBuzz: For a given range of numbers (e.g., 1 to 100), print "Fizz" if the number is
# divisible by 3, "Buzz" if it's divisible by 5, and "FizzBuzz" if it's divisible by both. Otherwise,
# print the number itself.

# %%
for num in range(1, 101):
    if num % 3 == 0 and num % 5 == 0:
        print("FizzBuzz")
    elif num % 3 == 0:
        print("Fizz")
    elif num % 5 == 0:
        print("Buzz")
    else:
        print(num)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# 2. Electricity Bill calculator
# Create a bill calculator where the user enters the number of units consumed. ₹5 per
# unit for the first 100 units ₹7 per unit for the next 100 units (from 101 to 200) ₹10 per
# unit for any units above 200 Calculate and display the total electricity bill.
# Sample Input:
# Enter units consumed: 245
# Sample Output:
# Total Bill Amount: ₹1650

# %%
units = int(input("Enter units consumed: "))

if units <= 100:
    bill = units * 5

elif units <= 200:
    bill = (100 * 5) + (units - 100) * 7

else:
    bill = (100 * 5) + (100 * 7) + (units - 200) * 10

print("Total Bill Amount: ₹", bill)
# Out:
# Enter units consumed: 5
# Total Bill Amount: ₹ 25

# %% [markdown]
# 3. Display a pattern for a simple progress indicator.
# *
# **
# ***
# ****
# *****

# %%
for i in range(1, 6):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# 4. Palindrome
# Develop a Python program that checks whether a given word or phrase is a
# palindrome.
# Sample input
# Enter num or string to be checked = 121
# Sample Output
# Given num/string is Palindrome

# %%
text = input("Enter num or string to be checked: ")


clean_text = text.replace(" ", "").lower()

if clean_text == clean_text[::-1]:
    print("Given num/string is Palindrome")
else:
    print("Given num/string is NOT Palindrome")
# Out:
# Enter num or string to be checked: 121
# Given num/string is Palindrome
